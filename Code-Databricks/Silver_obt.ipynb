# %%
from delta.tables import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
import pyspark.sql.functions as f

# %%
df = spark.read.table("ubercat.bronze.rides_raw")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th><th>topic</th><th>partition</th><th>offset</th><th>timestamp</th><th>timestampType</th><th>rides</th></tr></thead><tbody><tr><td>null</td><td>...</td><td>engevent</td><td>0</td><td>0</td><td>2026-03-29T00:51:15.442Z</td><td>0</td><td>{"ride_id": "cc05f2d7-71cd-44d1-9239-e48a08a5ef34", "confirmation_number": "cT0-4636-Sz42", "passenger_id": "df35dee5-18c0-4a8b-ac5b-f92d9724d7e0", "driver_id": "6cf20931-fde7-4135-b36d-ff57f69b8a7a", "vehicle_id": "93d85c20-0e59-4781-b15a-ca162b65d7fe", "pickup_location_id": "e374e3a3-e1b7-4c59-bda4-24501bce0a91", "dropoff_location_id": "8ce916d8-6de3-4f54-94d8-f04438d82afd", "vehicle_type_id": 1, "vehicle_make_id": 6, "payment_method_id": 2, "ride_status_id": 1, "pickup_city_id": 7, "dropoff_city_id": 9, "cancellation_reason_id": 4, "passenger_name": "Julia Stevenson", "passenger_email": "thenson@example.com", "passenger_phone": "884-401-2103", "driver_name": "Mr. John Johnson DVM", "driver_rating": 4.53, "driver_phone": "+1-973-783-0514x70695", "driver_license": "cS-ark-5446436", "vehicle_model": "Community", "vehicle_color": "White", "license_plate": "IBR-6879", "pickup_address": "9062 Norton Lake Apt. 694, Douglasmouth, MP 92535", "pickup_latitude": 80.795334, "pickup_longitude": 92.867553, "dropoff_address": "3430 Andrew Locks, Patriciahaven, WY 40704", "dropoff_latitude": -81.715401, "dropoff_longitude": 69.072872, "distance_miles": 2.27, "duration_minutes": 104, "booking_timestamp": "2026-03-07T00:49:14.202526", "pickup_timestamp": "2026-03-07T00:51:14.202526", "dropoff_timestamp": "2026-03-07T02:35:14.202526", "base_fare": 2.5, "distance_fare": 3.97, "time_fare": 36.4, "surge_multiplier": 2.03, "subtotal": 87.03, "tip_amount": 3, "total_fare": 90.03, "rating": null}</td></tr><tr><td>null</td><td>...</td><td>engevent</td><td>0</td><td>1</td><td>2026-03-29T12:11:06.023Z</td><td>0</td><td>{"ride_id": "4a4da58e-0cbb-49b6-b051-84bd9330533b", "confirmation_number": "PC9-6739-TL74", "passenger_id": "3614c96e-1bf3-4ecc-a58c-137ce72a4508", "driver_id": "cc68cdfe-3dd3-4b1b-ac5a-5c54e6e91f4d", "vehicle_id": "707df1b9-1e9b-4238-af91-449e7057af02", "pickup_location_id": "772b047b-49e0-4a77-a1bb-057b12081a52", "dropoff_location_id": "f8be0047-325d-44e0-a921-416361e69d26", "vehicle_type_id": 1, "vehicle_make_id": 7, "payment_method_id": 4, "ride_status_id": 1, "pickup_city_id": 10, "dropoff_city_id": 1, "cancellation_reason_id": 4, "passenger_name": "Traci Chapman", "passenger_email": "jmosley@example.com", "passenger_phone": "6946566399", "driver_name": "Jennifer Welch", "driver_rating": 4.79, "driver_phone": "001-932-336-1715x874", "driver_license": "eE-yfM-0122791", "vehicle_model": "Entire", "vehicle_color": "Blue", "license_plate": "Qrv-2849", "pickup_address": "7702 Valdez Orchard Suite 701, North Veronicamouth, DC 64067", "pickup_latitude": -54.21212, "pickup_longitude": -87.025582, "dropoff_address": "7254 Leslie Underpass, Brownfurt, MD 51933", "dropoff_latitude": -67.21086, "dropoff_longitude": 148.992699, "distance_miles": 2.94, "duration_minutes": 27, "booking_timestamp": "2026-03-09T22:02:04.954301", "pickup_timestamp": "2026-03-09T22:11:04.954301", "dropoff_timestamp": "2026-03-09T22:38:04.954301", "base_fare": 2.5, "distance_fare": 5.14, "time_fare": 9.45, "surge_multiplier": 1.29, "subtotal": 22.05, "tip_amount": 2, "total_fare": 24.05, "rating": 1}</td></tr><tr><td>null</td><td>...</td><td>engevent</td><td>0</td><td>2</td><td>2026-03-29T14:09:56.170Z</td><td>0</td><td>{"ride_id": "118f7d32-9243-47b3-8141-1c9cb9a33480", "confirmation_number": "Gi2-8795-Cs22", "passenger_id": "8813df05-25bf-4108-a6db-a85e2316d77d", "driver_id": "008e897a-7639-41c2-8d3c-4172272d3fee", "vehicle_id": "3f8fd4bb-7148-44fa-a8be-03afa467b55d", "pickup_location_id": "09b79c70-8ca1-4382-baaa-0f35ac164ade", "dropoff_location_id": "ac630aa2-79cd-4136-ba09-b31f4cecc19c", "vehicl ...

# %%
df = spark.sql("select * from ubercat.bronze.bulk_rides")
rides_schema = df.schema
rides_schema
# Out:
# StructType([StructField('ride_id', StringType(), True), StructField('confirmation_number', StringType(), True), StructField('passenger_id', StringType(), True), StructField('driver_id', StringType(), True), StructField('vehicle_id', StringType(), True), StructField('pickup_location_id', StringType(), True), StructField('dropoff_location_id', StringType(), True), StructField('vehicle_type_id', LongType(), True), StructField('vehicle_make_id', LongType(), True), StructField('payment_method_id', LongType(), True), StructField('ride_status_id', LongType(), True), StructField('pickup_city_id', LongType(), True), StructField('dropoff_city_id', LongType(), True), StructField('cancellation_reason_id', LongType(), True), StructField('passenger_name', StringType(), True), StructField('passenger_email', StringType(), True), StructField('passenger_phone', StringType(), True), StructField('driver_name', StringType(), True), StructField('driver_rating', DoubleType(), True), StructField('driver_phone', StringType(), True), StructField('driver_license', StringType(), True), StructField('vehicle_model', StringType(), True), StructField('vehicle_color', StringType(), True), StructField('license_plate', StringType(), True), StructField('pickup_address', StringType(), True), StructField('pickup_latitude', DoubleType(), True), StructField('pickup_longitude', DoubleType(), True), StructField('dropoff_address', StringType(), True), StructField('dropoff_latitude', DoubleType(), True), StructField('dropoff_longitude', DoubleType(), True), StructField('distance_miles', DoubleType(), True), StructField('duration_minutes', LongType(), True), StructField('booking_timestamp', StringType(), True), StructField('pickup_timestamp', StringType(), True), StructField('dropoff_timestamp', StringType(), True), StructField('base_fare', DoubleType(), True), StructField('distance_fare', DoubleType(), True), StructField('time_fare', DoubleType(), True), StructField('surge_multiplier', DoubleType(), True), StructField('subtotal', DoubleType(), True), StructField('tip_amount', DoubleType(), True), StructField('total_fare', DoubleType(), True), StructField('rating', DoubleType(), True)])

# %%
rides_schema = StructType([StructField('ride_id', StringType(), True), StructField('confirmation_number', StringType(), True), StructField('passenger_id', StringType(), True), StructField('driver_id', StringType(), True), StructField('vehicle_id', StringType(), True), StructField('pickup_location_id', StringType(), True), StructField('dropoff_location_id', StringType(), True), StructField('vehicle_type_id', LongType(), True), StructField('vehicle_make_id', LongType(), True), StructField('payment_method_id', LongType(), True), StructField('ride_status_id', LongType(), True), StructField('pickup_city_id', LongType(), True), StructField('dropoff_city_id', LongType(), True), StructField('cancellation_reason_id', LongType(), True), StructField('passenger_name', StringType(), True), StructField('passenger_email', StringType(), True), StructField('passenger_phone', StringType(), True), StructField('driver_name', StringType(), True), StructField('driver_rating', DoubleType(), True), StructField('driver_phone', StringType(), True), StructField('driver_license', StringType(), True), StructField('vehicle_model', StringType(), True), StructField('vehicle_color', StringType(), True), StructField('license_plate', StringType(), True), StructField('pickup_address', StringType(), True), StructField('pickup_latitude', DoubleType(), True), StructField('pickup_longitude', DoubleType(), True), StructField('dropoff_address', StringType(), True), StructField('dropoff_latitude', DoubleType(), True), StructField('dropoff_longitude', DoubleType(), True), StructField('distance_miles', DoubleType(), True), StructField('duration_minutes', LongType(), True), StructField('booking_timestamp', TimestampType(), True), StructField('pickup_timestamp', StringType(), True), StructField('dropoff_timestamp', StringType(), True), StructField('base_fare', DoubleType(), True), StructField('distance_fare', DoubleType(), True), StructField('time_fare', DoubleType(), True), StructField('surge_multiplier', DoubleType(), True), StructField('subtotal', DoubleType(), True), StructField('tip_amount', DoubleType(), True), StructField('total_fare', DoubleType(), True), StructField('rating', DoubleType(), True)])

# %%
df = spark.read.table("ubercat.bronze.rides_raw")
df_parsed = df.withColumn("parsed_rides", from_json(col("rides"), rides_schema)).select("parsed_rides.*")
display(df_parsed)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ride_id</th><th>confirmation_number</th><th>passenger_id</th><th>driver_id</th><th>vehicle_id</th><th>pickup_location_id</th><th>dropoff_location_id</th><th>vehicle_type_id</th><th>vehicle_make_id</th><th>payment_method_id</th><th>ride_status_id</th><th>pickup_city_id</th><th>dropoff_city_id</th><th>cancellation_reason_id</th><th>passenger_name</th><th>passenger_email</th><th>passenger_phone</th><th>driver_name</th><th>driver_rating</th><th>driver_phone</th><th>driver_license</th><th>vehicle_model</th><th>vehicle_color</th><th>license_plate</th><th>pickup_address</th><th>pickup_latitude</th><th>pickup_longitude</th><th>dropoff_address</th><th>dropoff_latitude</th><th>dropoff_longitude</th><th>distance_miles</th><th>duration_minutes</th><th>booking_timestamp</th><th>pickup_timestamp</th><th>dropoff_timestamp</th><th>base_fare</th><th>distance_fare</th><th>time_fare</th><th>surge_multiplier</th><th>subtotal</th><th>tip_amount</th><th>total_fare</th><th>rating</th></tr></thead><tbody><tr><td>cc05f2d7-71cd-44d1-9239-e48a08a5ef34</td><td>cT0-4636-Sz42</td><td>df35dee5-18c0-4a8b-ac5b-f92d9724d7e0</td><td>6cf20931-fde7-4135-b36d-ff57f69b8a7a</td><td>93d85c20-0e59-4781-b15a-ca162b65d7fe</td><td>e374e3a3-e1b7-4c59-bda4-24501bce0a91</td><td>8ce916d8-6de3-4f54-94d8-f04438d82afd</td><td>1</td><td>6</td><td>2</td><td>1</td><td>7</td><td>9</td><td>4</td><td>Julia Stevenson</td><td>thenson@example.com</td><td>884-401-2103</td><td>Mr. John Johnson DVM</td><td>4.53</td><td>+1-973-783-0514x70695</td><td>cS-ark-5446436</td><td>Community</td><td>White</td><td>IBR-6879</td><td>9062 Norton Lake Apt. 694, Douglasmouth, MP 92535</td><td>80.795334</td><td>92.867553</td><td>3430 Andrew Locks, Patriciahaven, WY 40704</td><td>-81.715401</td><td>69.072872</td><td>2.27</td><td>104</td><td>2026-03-07T00:49:14.202Z</td><td>2026-03-07T00:51:14.202526</td><td>2026-03-07T02:35:14.202526</td><td>2.5</td><td>3.97</td><td>36.4</td><td>2.03</td><td>87.03</td><td>3.0</td><td>90.03</td><td>null</td></tr><tr><td>4a4da58e-0cbb-49b6-b051-84bd9330533b</td><td>PC9-6739-TL74</td><td>3614c96e-1bf3-4ecc-a58c-137ce72a4508</td><td>cc68cdfe-3dd3-4b1b-ac5a-5c54e6e91f4d</td><td>707df1b9-1e9b-4238-af91-449e7057af02</td><td>772b047b-49e0-4a77-a1bb-057b12081a52</td><td>f8be0047-325d-44e0-a921-416361e69d26</td><td>1</td><td>7</td><td>4</td><td>1</td><td>10</td><td>1</td><td>4</td><td>Traci Chapman</td><td>jmosley@example.com</td><td>6946566399</td><td>Jennifer Welch</td><td>4.79</td><td>001-932-336-1715x874</td><td>eE-yfM-0122791</td><td>Entire</td><td>Blue</td><td>Qrv-2849</td><td>7702 Valdez Orchard Suite 701, North Veronicamouth, DC 64067</td><td>-54.21212</td><td>-87.025582</td><td>7254 Leslie Underpass, Brownfurt, MD 51933</td><td>-67.21086</td><td>148.992699</td><td>2.94</td><td>27</td><td>2026-03-09T22:02:04.954Z</td><td>2026-03-09T22:11:04.954301</td><td>2026-03-09T22:38:04.954301</td><td>2.5</td><td>5.14</td><td>9.45</td><td>1.29</td><td>22.05</td><td>2.0</td><td>24.05</td><td>1.0</td></tr><tr><td>118f7d32-9243-47b3-8141-1c9cb9a33480</td><td>Gi2-8795-Cs22</td><td>8813df05-25bf-4108-a6db-a85e2316d77d</td><td>008e897a-7639-41c2-8d3c-4172272d3fee</td><td>3f8fd4bb-7148-44fa-a8be-03afa467b55d</td><td>09b79c70-8ca1-4382-baaa-0f35ac164ade</td><td>ac630aa2-79cd-4136-ba09-b31f4cecc19c</td><td>2</td><td>2</td><td>4</td><td>2</td><td>4</td><td>7</td><td>4</td><td>Cynthia Robinson</td><td>laurenellis@example.com</td><td>466-352-6720x996</td><td>Teresa Shelton</td><td>4.31</td><td>287-747-5779</td><td>gz-rkU-7893635</td><td>Accept</td><td>Black</td><td>ZOb-2145</td><td>43260 Olivia Mountains Apt. 594, New Katie, KS 50311</td><td>-68.112337</td><td>66.057506</td><td>38228 Gail Highway, Jonathantown, VA 10998</td><td>-79.991119</td><td>14.006797</td><td>14.9</td><td>58</td><td>2026-02-27T14:08:55.037Z</td><td>2026-02-27T14:09:55.037491</td><td>2026-02-27T15:07:55.037491</t ...

# %%
jinja_config = [
    {
        "table" : "ubercat.bronze.staging_rides staging_rides",
        "select" : 'staging_rides.ride_id, staging_rides.confirmation_number, staging_rides.passenger_id, staging_rides.driver_id, staging_rides.vehicle_id, staging_rides.pickup_location_id, staging_rides.dropoff_location_id, staging_rides.vehicle_type_id, staging_rides.vehicle_make_id, staging_rides.payment_method_id, staging_rides.ride_status_id, staging_rides.pickup_city_id, staging_rides.dropoff_city_id, staging_rides.cancellation_reason_id, staging_rides.passenger_name, staging_rides.passenger_email, staging_rides.passenger_phone, staging_rides.driver_name, staging_rides.driver_rating, staging_rides.driver_phone, staging_rides.driver_license, staging_rides.vehicle_model, staging_rides.vehicle_color, staging_rides.license_plate, staging_rides.pickup_address, staging_rides.pickup_latitude, staging_rides.pickup_longitude, staging_rides.dropoff_address, staging_rides.dropoff_latitude, staging_rides.dropoff_longitude, staging_rides.distance_miles, staging_rides.duration_minutes, staging_rides.booking_timestamp, staging_rides.pickup_timestamp, staging_rides.dropoff_timestamp, staging_rides.base_fare, staging_rides.distance_fare, staging_rides.time_fare, staging_rides.surge_multiplier, staging_rides.subtotal, staging_rides.tip_amount, staging_rides.total_fare, staging_rides.rating',
        "where" : ""
    },
    {
        "table" : "ubercat.bronze.map_vehicle_makes map_vehicle_makes",
        "select" : "map_vehicle_makes.vehicle_make",
        "where" : "",
        "on" : "staging_rides.vehicle_make_id = map_vehicle_makes.vehicle_make_id"
    },
    {
        "table" : "ubercat.bronze.map_vehicle_types map_vehicle_types",
        "select" : "map_vehicle_types.vehicle_type,map_vehicle_types.description,map_vehicle_types.base_rate,map_vehicle_types.per_mile,map_vehicle_types.per_minute",
        "where" : "",
        "on" : "staging_rides.vehicle_type_id = map_vehicle_types.vehicle_type_id"
    },
    {
        "table" : "ubercat.bronze.map_ride_statuses map_ride_statuses",
        "select" : "map_ride_statuses.ride_status",
        "where" : "",
        "on" : "staging_rides.ride_status_id = map_ride_statuses.ride_status_id"
    },
    {
        "table" : "ubercat.bronze.map_payment_methods map_payment_methods",
        "select" : "map_payment_methods.payment_method, map_payment_methods.is_card, map_payment_methods.requires_auth",
        "where" : "",
        "on" : "staging_rides.payment_method_id = map_payment_methods.payment_method_id"
    },
    {
        "table" : "ubercat.bronze.map_cities map_cities",
        "select" : "map_cities.city as pickup_city, map_cities.state, map_cities.region, map_cities.updated_at as city_updated_at",
        "where" : "",
        "on" : "staging_rides.pickup_city_id = map_cities.city_id"
    },
    {
        "table" : "ubercat.bronze.map_cancellation_reasons map_cancellation_reasons",
        "select" : "map_cancellation_reasons.cancellation_reason",
        "where" : "",
        "on" : "staging_rides.cancellation_reason_id = map_cancellation_reasons.cancellation_reason_id"
    }
]

# %%
from jinja2 import Template

# create dynamic sql queries
jinja_str = """

    SELECT 
        {% for config in jinja_config %}
            {{ config.select }} 
                {% if not loop.last %}
                    ,
                {% endif %}
        {% endfor %}
    FROM 
        {% for config in jinja_config %}
            {% if loop.first %}
                {{ config.table }}
            {% else %}
                LEFT JOIN {{ config.table }} ON {{ config.on }}
            {% endif %}
        {% endfor %}
   
        {% for  config in jinja_config %}

            {% if loop.first %}
               {% if config.where != "" %} 
                WHERE
                {% endif %}
            {% endif %}

            {{ config.where }}
                {% if not loop.last %}
                  {% if config.where != "" %}
                    AND
                  {% endif %}  
                {% endif %}
        {% endfor %}
"""


template = Template(jinja_str)
rendered_template = template.render(jinja_config=jinja_config)
print(rendered_template)
# Out:
#     SELECT
#
#             staging_rides.ride_id, staging_rides.confirmation_number, staging_rides.passenger_id, staging_rides.driver_id, staging_rides.vehicle_id, staging_rides.pickup_location_id, staging_rides.dropoff_location_id, staging_rides.vehicle_type_id, staging_rides.vehicle_make_id, staging_rides.payment_method_id, staging_rides.ride_status_id, staging_rides.pickup_city_id, staging_rides.dropoff_city_id, staging_rides.cancellation_reason_id, staging_rides.passenger_name, staging_rides.passenger_email, staging_rides.passenger_phone, staging_rides.driver_name, staging_rides.driver_rating, staging_rides.driver_phone, staging_rides.driver_license, staging_rides.vehicle_model, staging_rides.vehicle_color, staging_rides.license_plate, staging_rides.pickup_address, staging_rides.pickup_latitude, staging_rides.pickup_longitude, staging_rides.dropoff_address, staging_rides.dropoff_latitude, staging_rides.dropoff_longitude, staging_rides.distance_miles, staging_rides.duration_minutes, staging_rides.booking_timestamp, staging_rides.pickup_timestamp, staging_rides.dropoff_timestamp, staging_rides.base_fare, staging_rides.distance_fare, staging_rides.time_fare, staging_rides.surge_multiplier, staging_rides.subtotal, staging_rides.tip_amount, staging_rides.total_fare, staging_rides.rating
#
#                     ,
#
#
#             map_vehicle_makes.vehicle_make
#
#                     ,
#
#
#             map_vehicle_types.vehicle_type,map_vehicle_types.description,map_vehicle_types.base_rate,map_vehicle_types.per_mile,map_vehicle_types.per_minute
#
#                     ,
#
#
#             map_ride_statuses.ride_status
#
#                     ,
#
#
#             map_payment_methods.payment_method, map_payment_methods.is_card, map_payment_methods.requires_auth
#
#                     ,
#
#
#             map_cities.city as pickup_city, map_cities.state, map_cities.region, map_cities.updated_at as city_updated_at
#
#                     ,
#
#
#             map_cancellation_reasons.cancellation_reason
#
#
#     FROM
#
#
#                 ubercat.bronze.staging_rides staging_rides
#
#
#
#                 LEFT JOIN ubercat.bronze.map_vehicle_makes map_vehicle_makes ON staging_rides.vehicle_make_id = map_vehicle_makes.vehicle_make_id
#
#
#
#                 LEFT JOIN ubercat.bronze.map_vehicle_types map_vehicle_types ON staging_rides.vehicle_type_id = map_vehicle_types.vehicle_type_id
#
#
#
#                 LEFT JOIN ubercat.bronze.map_ride_statuses map_ride_statuses ON staging_rides.ride_status_id = map_ride_statuses.ride_status_id
#
#
#
#                 LEFT JOIN ubercat.bronze.map_payment_methods map_payment_methods ON staging_rides.payment_method_id = map_payment_methods.payment_method_id
#
#
#
#                 LEFT JOIN ubercat.bronze.map_cities map_cities ON staging_rides.pickup_city_id = map_cities.city_id
#
#
#
#                 LEFT JOIN ubercat.bronze.map_cancellation_reasons map_cancellation_reasons ON staging_rides.cancellation_reason_id = map_cancellation_reasons.cancellation_reason_id

# %%
df = spark.sql(rendered_template)
df.head(10)
# Out:
# [Row(ride_id='0d16a6a8-bd0d-4185-a99e-49fc0be075c3', confirmation_number='MW4-1943-ai01', passenger_id='aefbbe7a-f6a6-4d81-b50d-ae6fdb79b19d', driver_id='9b972231-c056-483c-b15f-73a4283635cf', vehicle_id='4e801840-613d-4805-a652-965c6236300c', pickup_location_id='a1e4eb35-37f3-4825-bf83-f052e51eccb1', dropoff_location_id='f2a65df8-adec-4801-9b11-9cfa5b3e9fc8', vehicle_type_id=1, vehicle_make_id=5, payment_method_id=4, ride_status_id=1, pickup_city_id=6, dropoff_city_id=10, cancellation_reason_id=4, passenger_name='Seth Watson', passenger_email='christopherzamora@example.org', passenger_phone='708-961-7899x773', driver_name='Kristen Harding', driver_rating=4.94, driver_phone='001-691-788-6691x59174', driver_license='To-FyD-4489453', vehicle_model='Provide', vehicle_color='Blue', license_plate='yQC-2361', pickup_address='4187 Edward Islands Apt. 011, Lake Tiffanyberg, AL 94011', pickup_latitude=1.138997, pickup_longitude=-9.72479, dropoff_address='8575 Craig Estates, Floresstad, TX 27223', dropoff_latitude=78.503042, dropoff_longitude=-155.48478, distance_miles=26.53, duration_minutes=47, booking_timestamp=datetime.datetime(2026, 2, 10, 12, 44, 6, 539114), pickup_timestamp='2026-02-10T12:46:06.539114', dropoff_timestamp='2026-02-10T13:33:06.539114', base_fare=2.5, distance_fare=46.43, time_fare=16.45, surge_multiplier=1.03, subtotal=67.34, tip_amount=0.0, total_fare=67.34, rating=5.0, vehicle_make='Nissan', vehicle_type='UberX', description='Standard', base_rate=2.5, per_mile=1.75, per_minute=0.35000000000000003, ride_status='Completed', payment_method='Cash', is_card=False, requires_auth=False, pickup_city='Philadelphia', state='PA', region='Northeast', city_updated_at=datetime.datetime(2026, 3, 30, 0, 24, 7, 377000), cancellation_reason=None),
#  Row(ride_id='4ff030b3-2f07-4907-be74-52a5796450bd', confirmation_number='Ey2-0752-Cb82', passenger_id='8509994a-2e5c-4dc7-869d-105c67accd5f', driver_id='88cc621b-42c0-42c3-a4b6-ae8c3eb9d682', vehicle_id='9b6339a8-b3d1-43ff-8219-5c6bb964a4c2', pickup_location_id='5dc731ac-a31e-41f7-b3ab-f3d304caee89', dropoff_location_id='95680c00-8a92-4ca2-aa14-619057172e67', vehicle_type_id=4, vehicle_make_id=3, payment_method_id=4, ride_status_id=1, pickup_city_id=8, dropoff_city_id=8, cancellation_reason_id=4, passenger_name='Brandon Patel', passenger_email='taylorholly@example.com', passenger_phone='001-984-630-7908x231', driver_name='Donna Arnold', driver_rating=4.26, driver_phone='001-967-966-7374x68648', driver_license='Xq-eMJ-0258471', vehicle_model='Physical', vehicle_color='Black', license_plate='VVC-4056', pickup_address='2464 Shawna Motorway Apt. 453, Lake Margaret, PW 19436', pickup_latitude=-82.76087, pickup_longitude=90.031581, dropoff_address='PSC 6805, Box 9387, APO AE 73703', dropoff_latitude=-4.448683, dropoff_longitude=-110.631583, distance_miles=17.66, duration_minutes=48, booking_timestamp=datetime.datetime(2026, 2, 24, 22, 45, 6, 540114), pickup_timestamp='2026-02-24T22:46:06.540114', dropoff_timestamp='2026-02-24T23:34:06.540114', base_fare=2.5, distance_fare=30.91, time_fare=16.8, surge_multiplier=1.25, subtotal=62.76, tip_amount=1.0, total_fare=63.76, rating=None, vehicle_make='Ford', vehicle_type='Uber Comfort', description='Comfortable', base_rate=3.0, per_mile=2.0, per_minute=0.4, ride_status='Completed', payment_method='Cash', is_card=False, requires_auth=False, pickup_city='San Diego', state='CA', region='West', city_updated_at=datetime.datetime(2026, 3, 30, 0, 24, 7, 377000), cancellation_reason=None),
#  Row(ride_id='7dad1dc4-e995-427a-8c1f-1d8f7ee6dba5', confirmation_number='NL9-0098-lQ96', passenger_id='393f43db-923a-4ccb-bc1c-502cc8415799', driver_id='aa992a93-74b4-496c-b4fc-41d69b60db4b', vehicle_id='ac467849-b0a7-4557-ba22-87e47bf03978', pickup_location_id='f894a59d-dc48-4a1d-ad9c-b9bfc13b09d6', dropoff_location_id='59226f4c-299a-4dbb-8810-6fcbce76ce84', vehicle_type_id=2, vehicle_make_id=1, payment_method_id=4, ride_status_id=2, pickup_city_id=10, dropoff_city_id=9, cancellation_reason_id=2, passenger_name='Valerie Boyd', passenger_email='aaron04@example.com', passenger_phone='442.608.1757x7550', driver_name='Anthony Sullivan', driver_rating=4.97, driver_phone='001-719-780-3063', driver_license='mU-ngM-6948040', vehicle_model='Sort', vehicle_color='Gray', license_plate='SYJ-7796', pickup_address='7126 Sarah Divide Apt. 572, Smithberg, CO 07988', pickup_latitude=-34.638946, pickup_longitude=-123.067832, dropoff_address='PSC 3706, Box 2586, APO AE 92913', dropoff_latitude=83.550515, dropoff_longitude=167.485603, distance_miles=18.48, duration_minutes=71, booking_timestamp=datetime.datetime(2026, 1, 29, 3, 36, 6, 540114), pickup_timestamp='2026-01-29T03:46:06.540114', dropoff_timestamp='2026-01-29T04:57:06.540114', base_fare=2.5, distance_fare=32.34, time_fare=24.85, surge_multiplier=1.25, subtotal=74.61, tip_amount=3.0, total_fare=77.61, rating=None, vehicle_make='Toyota', vehicle_type='UberXL', description='Extra Large', base_rate=3.5, per_mile=2.25, per_minute=0.45, ride_status='Cancelled', payment_method='Cash', is_card=False, requires_auth=False, pickup_city='San Jose', state='CA', region='West', city_updated_at=datetime.datetime(2026, 3, 30, 0, 24, 7, 377000), cancellation_reason='Passenger cancelled'),
#  Row(ride_id='33e23da9-a79e-4ffd-aca4-dd289ffc7208', confirmation_number='NM3-8029-aE82', passenger_id='73f3a39a-5be8-457e-a6c5-b6ec93592992', driver_id='51dd5d17-bc42-4210-af64-e94e4e3d6fea', vehicle_id='e9ba7089-73c9-46c8-8ab2-d829be3c698f', pickup_location_id='1783ca0b-b490-4f4c-a480-1c9ebbc0fbbd', dropoff_location_id='743470aa-301f-40c4-8567-9b8050dfde31', vehicle_type_id=2, vehicle_make_id=3, payment_method_id=2, ride_status_id=1, pickup_city_id=2, dropoff_city_id=4, cancellation_reason_id=3, passenger_name='Brandon Hawkins', passenger_email='qgreene@example.net', passenger_phone='(991)889-3470', driver_name='Caitlin Little', driver_rating=4.5, driver_phone='579.262.1572', driver_license='hT-MCQ-3778978', vehicle_model='Drug', vehicle_color='Black', license_plate='DDL-7284', pickup_address='078 Daniels Cove Suite 823, Fisherville, GA 29483', pickup_latitude=-78.000591, pickup_longitude=103.355793, dropoff_address='4978 Kathryn Lodge, New Melanie, NC 91499', dropoff_latitude=53.325673, dropoff_longitude=-12.407711, distance_miles=49.3, duration_minutes=119, booking_timestamp=datetime.datetime(2026, 2, 9, 1, 39, 6, 541114), pickup_timestamp='2026-02-09T01:46:06.541114', dropoff_timestamp='2026-02-09T03:45:06.541114', base_fare=2.5, distance_fare=86.27, time_fare=41.65, surge_multiplier=1.8599999999999999, subtotal=242.58, tip_amount=5.0, total_fare=247.58, rating=2.0, vehicle_make='Ford', vehicle_type='UberXL', description='Extra Large', base_rate=3.5, per_mile=2.25, per_minute=0.45, ride_status='Completed', payment_method='Debit Card', is_card=True, requires_auth=True, pickup_city='Los Angelas', state='CA', region='West', city_updated_at=datetime.datetime(2026, 3, 30, 0, 24, 7, 377000), cancellation_reason='No show'),
#  Row(ride_id='240c29d5-dd25-4b9e-9f7e-c4db765e2f6c', confirmation_number='XW1-7184-sG09', passenger_id='0fb00760-abff-46ef-ba3f-ab272a31647b', driver_id='c549d9c2-a8e3-4379-8d21-a930f640137e', vehicle_id='c441cb55-148b-4582-a1bd-9645ebae4066', pickup_location_id='597dea67-1f25-44a6-b32f-48b6c329c06b', dropoff_location_id='1ef202a1-a0a0-4aa1-b6f7-67231f6faedd', vehicle_type_id=1, vehicle_make_id=6, payment_method_id=4, ride_status_id=1, pickup_city_id=7, dropoff_city_id=2, cancellation_reason_id=4, passenger_name='Mary Wright', passenger_email='sullivanraymond@example.com', passenger_phone='776-473-1346x54956', driver_name='Danielle Elliott', driver_rating=4.73, driver_phone='739-354-7853', driver_license='KH-pqn-6482536', vehicle_model='Air', vehicle_color='Silver', license_plate='uxM-5123', pickup_address='3432 Jeffrey Extensions, Port Austinshire, ID 69960', pickup_latitude=-88.890578, pickup_longitude=-96.852314, dropoff_address='3666 Samantha Streets Apt. 293, New Randallton, CT 46421', dropoff_latitude=30.449397, dropoff_longitude=107.013401, distance_miles=41.26, duration_minutes=93, booking_timestamp=datetime.datetime(2026, 2, 15, 16, 41, 6, 541114), pickup_timestamp='2026-02-15T16:46:06.541114', dropoff_timestamp='2026-02-15T18:19:06.541114', base_fare=2.5, distance_fare=72.2, time_fare=32.55, surge_multiplier=1.73, subtotal=185.54, tip_amount=0.0, total_fare=185.54, rating=None, vehicle_make='BMW', vehicle_type='UberX', description='Standard', base_rate=2.5, per_mile=1.75, per_minute=0.35000000000000003, ride_status='Completed', payment_method='Cash', is_card=False, requires_auth=False, pickup_city='San Antonio', state='TX', region='South', city_updated_at=datetime.datetime(2026, 3, 30, 0, 24, 7, 377000), cancellation_reason=None),
#  Row(ride_id='8b6342ed-2cbc-4af8-ad29-8459d75b7bcb', confirmation_number='IT6-9865-WR64', passenger_id='24996c4d-3660-489d-8b30-cbc68f048290', driver_id='1b4ae892-77fe-4e57-9094-06da044a03f7', vehicle_id='d700a65d-46f2-4251-90c6-1633badbafb5', pickup_location_id='99a26f2d-da09-4186-9aab-0e9b7b9df691', dropoff_location_id='90925109-2118-4b48-8b3d-d0f43cc72974', vehicle_type_id=4, vehicle_make_id=1, payment_method_id=4, ride_status_id=1, pickup_city_id=7, dropoff_city_id=1, cancellation_reason_id=4, passenger_name='Mr. Michael Bridges', passenger_email='stefanie25@example.net', passenger_phone='713-532-5213', driver_name='Julia Mitchell', driver_rating=4.72, driver_phone='001-864-576-6397x1432', driver_license='KU-GHg-2555435', vehicle_model='Citizen', vehicle_color='Red', license_plate='Amm-5068', pickup_address='USNS Mccoy, FPO AE 85126', pickup_latitude=38.793419, pickup_longitude=153.834308, dropoff_address='PSC 4666, Box 4244, APO AE 89027', dropoff_latitude=-78.375696, dropoff_longitude=-144.08062, distance_miles=46.13, duration_minutes=19, booking_timestamp=datetime.datetime(2026, 2, 8, 4, 43, 6, 541114), pickup_timestamp='2026-02-08T04:46:06.541114', dropoff_timestamp='2026-02-08T05:05:06.541114', base_fare=2.5, distance_fare=80.73, time_fare=6.65, surge_multiplier=2.17, subtotal=195.04, tip_amount=0.0, total_fare=195.04, rating=None, vehicle_make='Toyota', vehicle_type='Uber Comfort', description='Comfortable', base_rate=3.0, per_mile=2.0, per_minute=0.4, ride_status='Completed', payment_method='Cash', is_card=False, requires_auth=False, pickup_city='San Antonio', state='TX', region='South', city_updated_at=datetime.datetime(2026, 3, 30, 0, 24, 7, 377000), cancellation_reason=None),
#  Row(ride_id='d77e8023-c1cf-4845-bc76-1f48f64981c0', confirmation_number='rI7-0041-Yi13', passenger_id='4509606b-d031-4fdf-9b61-3f7cdca1383a', driver_id='dd8a3413-086a-43e5-ad8e-9b34629c6219', vehicle_id='48e5bbf1-fb1f-4878-9ea1-bd8aa147380c', pickup_location_id='0aa9d45b-c940-4907-bc71-3d315011e1a2', dropoff_location_id='45495501-3cfd-474f-ad6a-1cbb4264376f', vehicle_type_id=3, vehicle_make_id=7, payment_method_id=4, ride_status_id=1, pickup_city_id=8, dropoff_city_id=2, cancellation_reason_id=4, passenger_name='Mark Mclean', passenger_email='travis14@example.com', passenger_phone='2093718143', driver_name='Melissa Oliver', driver_rating=4.83, driver_phone='571-758-5720', driver_license='dB-cjr-5841559', vehicle_model='Everybody', vehicle_color='Gray', license_plate='jnN-1965', pickup_address='290 Kyle Vista Apt. 687, South Jacobshire, KY 83357', pickup_latitude=-33.90852, pickup_longitude=-87.916584, dropoff_address='546 Lee Club, Port Alyssaborough, MP 40722', dropoff_latitude=-50.297146, dropoff_longitude=146.664556, distance_miles=12.13, duration_minutes=15, booking_timestamp=datetime.datetime(2026, 2, 11, 18, 45, 6, 542114), pickup_timestamp='2026-02-11T18:46:06.542114', dropoff_timestamp='2026-02-11T19:01:06.542114', base_fare=2.5, distance_fare=21.23, time_fare=5.25, surge_multiplier=1.5, subtotal=43.47, tip_amount=0.0, total_fare=43.47, rating=1.0, vehicle_make='Mercedes', vehicle_type='UberPOOL', description='Shared Ride', base_rate=2.0, per_mile=1.5, per_minute=0.30000000000000004, ride_status='Completed', payment_method='Cash', is_card=False, requires_auth=False, pickup_city='San Diego', state='CA', region='West', city_updated_at=datetime.datetime(2026, 3, 30, 0, 24, 7, 377000), cancellation_reason=None),
#  Row(ride_id='e934ef49-ed1a-450c-8849-1697cb99de48', confirmation_number='iB5-6597-Kw62', passenger_id='89409f0e-4e27-4076-979b-ba7f9a91612a', driver_id='1452b91e-228c-4333-b355-32e90548ae5e', vehicle_id='20991a5d-c8ff-4325-b230-7d7e768e005e', pickup_location_id='956d5ae6-a4d4-42dc-b5fa-99447e86eb24', dropoff_location_id='ca09af29-91d4-4eae-85f3-c1dad7e6fa64', vehicle_type_id=4, vehicle_make_id=2, payment_method_id=2, ride_status_id=1, pickup_city_id=5, dropoff_city_id=3, cancellation_reason_id=4, passenger_name='Kayla Baker', passenger_email='marklowe@example.net', passenger_phone='284.514.8756', driver_name='Melissa York', driver_rating=4.39, driver_phone='001-615-639-6418x6067', driver_license='gT-Bpy-4170413', vehicle_model='On', vehicle_color='Blue', license_plate='oaX-9630', pickup_address='31442 Mark Burg, Port Jonathanside, PA 69440', pickup_latitude=-50.189863, pickup_longitude=172.102594, dropoff_address='35775 Mckenzie Ford, East Wesleyburgh, NH 23575', dropoff_latitude=29.105364, dropoff_longitude=-15.309677, distance_miles=35.63, duration_minutes=71, booking_timestamp=datetime.datetime(2026, 2, 23, 15, 38, 6, 542114), pickup_timestamp='2026-02-23T15:46:06.542114', dropoff_timestamp='2026-02-23T16:57:06.542114', base_fare=2.5, distance_fare=62.35, time_fare=24.85, surge_multiplier=2.11, subtotal=189.27, tip_amount=1.0, total_fare=190.27, rating=None, vehicle_make='Honda', vehicle_type='Uber Comfort', description='Comfortable', base_rate=3.0, per_mile=2.0, per_minute=0.4, ride_status='Completed', payment_method='Debit Card', is_card=True, requires_auth=True, pickup_city='Phoenix', state='AZ', region='Southwest', city_updated_at=datetime.datetime(2026, 3, 30, 0, 24, 7, 377000), cancellation_reason=None),
#  Row(ride_id='4fee7c90-ace1-429c-a4a4-f1e31b0d22e5', confirmation_number='JR7-4854-uV96', passenger_id='c6697bf3-cfaf-433e-83ee-9354d970a68a', driver_id='9173c9f3-8835-4ada-b4d2-f3ed64460fc5', vehicle_id='fba4b28d-ad2e-4555-b29a-508654d62a47', pickup_location_id='4cceadd0-9694-494a-9181-09018c92b572', dropoff_location_id='893fa5e0-ae3a-42ea-be75-977a33e70bdc', vehicle_type_id=3, vehicle_make_id=3, payment_method_id=3, ride_status_id=1, pickup_city_id=7, dropoff_city_id=1, cancellation_reason_id=4, passenger_name='Mr. Benjamin Hunt', passenger_email='duffyleslie@example.org', passenger_phone='(242)295-7649', driver_name='Charles Webster MD', driver_rating=4.87, driver_phone='+1-881-801-1936x38730', driver_license='Ks-Bpq-5633281', vehicle_model='Sit', vehicle_color='Gray', license_plate='tIc-8441', pickup_address='4848 Blackburn Field Apt. 365, North Thomasborough, KS 58350', pickup_latitude=-37.316584, pickup_longitude=107.610232, dropoff_address='4646 Allen Path, Port Jamesland, ND 71918', dropoff_latitude=56.613364, dropoff_longitude=74.674737, distance_miles=38.57, duration_minutes=83, booking_timestamp=datetime.datetime(2026, 2, 26, 8, 39, 6, 543113), pickup_timestamp='2026-02-26T08:46:06.543113', dropoff_timestamp='2026-02-26T10:09:06.543113', base_fare=2.5, distance_fare=67.5, time_fare=29.05, surge_multiplier=1.3, subtotal=128.77, tip_amount=0.0, total_fare=128.77, rating=None, vehicle_make='Ford', vehicle_type='UberPOOL', description='Shared Ride', base_rate=2.0, per_mile=1.5, per_minute=0.30000000000000004, ride_status='Completed', payment_method='Digital Wallet', is_card=False, requires_auth=False, pickup_city='San Antonio', state='TX', region='South', city_updated_at=datetime.datetime(2026, 3, 30, 0, 24, 7, 377000), cancellation_reason=None),
#  Row(ride_id='f2c96366-d59a-4e6e-9840-c5e1d0b8a1db', confirmation_number='qN8-4081-pT53', passenger_id='fdf4f5d8-2cd1-49ec-ab29-ef4a7b6c3e8c', driver_id='d93f54a7-ec50-49a8-8082-3c6fd4b3af18', vehicle_id='cfc9b76f-a38f-4930-8d20-49e68b30d2c6', pickup_location_id='b7f3fb64-e8d5-4c07-bb6b-819e503158e4', dropoff_location_id='d68a7fea-845e-43b3-a1ed-f6958417fa76', vehicle_type_id=5, vehicle_make_id=2, payment_method_id=4, ride_status_id=1, pickup_city_id=10, dropoff_city_id=4, cancellation_reason_id=4, passenger_name='Lori Campos', passenger_email='xsmith@example.org', passenger_phone='864-690-8650x38872', driver_name='Jamie Kramer', driver_rating=4.55, driver_phone='366-912-3121', driver_license='CX-kMx-0963021', vehicle_model='Thousand', vehicle_color='Silver', license_plate='gNH-1959', pickup_address='915 Gibson Stream Apt. 399, Andreatown, MS 96724', pickup_latitude=-16.385885, pickup_longitude=137.675236, dropoff_address='0119 Walsh Crossroad, Dunlapborough, MA 28476', dropoff_latitude=47.836658, dropoff_longitude=174.663518, distance_miles=27.13, duration_minutes=29, booking_timestamp=datetime.datetime(2026, 2, 15, 1, 45, 6, 543113), pickup_timestamp='2026-02-15T01:46:06.543113', dropoff_timestamp='2026-02-15T02:15:06.543113', base_fare=2.5, distance_fare=47.48, time_fare=10.15, surge_multiplier=2.33, subtotal=140.1, tip_amount=0.0, total_fare=140.1, rating=None, vehicle_make='Honda', vehicle_type='Uber Black', description='Premium', base_rate=5.0, per_mile=3.5, per_minute=0.6000000000000001, ride_status='Completed', payment_method='Cash', is_card=False, requires_auth=False, pickup_city='San Jose', state='CA', region='West', city_updated_at=datetime.datetime(2026, 3, 30, 0, 24, 7, 377000), cancellation_reason=None)]
